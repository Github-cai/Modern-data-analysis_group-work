# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_classification

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

florida_data=pd.read_csv("https://github.com/Github-cai/Modern-data-analysis_group-work/blob/main/florida_data.csv")
Texas_data=pd.read_csv('https://raw.githubusercontent.com/Github-cai/Modern-data-analysis_group-work/main/Texas_data.csv')
New_York_data=pd.read_csv('https://raw.githubusercontent.com/Github-cai/Modern-data-analysis_group-work/main/New_York_data.csv')
California_data=pd.read_csv('https://raw.githubusercontent.com/Github-cai/Modern-data-analysis_group-work/main/California_data.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-9d9668ea7e1b> in <module>
#       6 plt.rcParams['axes.unicode_minus'] = False
#       7
# ----> 8 florida_data=pd.read_csv(r'/Users/zhangquandi/Desktop/florida_data.csv',sheet_name="florida")
#       9 Texas_data=pd.read_csv(r'/Users/zhangquandi/Desktop/Texas_data.csvx',sheet_name="Texas")
#      10 New_York_data=pd.read_csv(r'/Users/zhangquandi/Desktop/New_York_data.csv',sheet_name="New York")
#
# TypeError: read_csv() got an unexpected keyword argument 'sheet_name'

# %%
Max_Tem=florida_data["Max_Tem"]
Mortality_Num=florida_data["Mortality_Num"]
plt.figure(figsize=(8, 8))
plt.scatter(Max_Tem, Mortality_Num, marker='o')
plt.xlabel('Maximum Temperature') 
plt.ylabel('death toll') 
plt.title('florida')
plt.show()

# %%
Max_Tem=Texas_data["Max_Tem"]
Mortality_Num=Texas_data["Mortality_Num"]
plt.figure(figsize=(8, 8))
plt.scatter(Max_Tem, Mortality_Num, marker='o')
plt.xlabel('Maximum Temperature') 
plt.ylabel('death toll')  
plt.title('Texas')
plt.show()

# %%
Max_Tem=New_York_data["Max_Tem"]
Mortality_Num=New_York_data["Mortality_Num"]
plt.figure(figsize=(8, 8))
plt.scatter(Max_Tem, Mortality_Num, marker='o')
plt.xlabel('Maximum Temperature') 
plt.ylabel('death toll')  
plt.title('New York')
plt.show()

# %%
Max_Tem=California_data["Max_Tem"]
Mortality_Num=California_data["Mortality_Num"]
plt.figure(figsize=(8, 8))
plt.scatter(Max_Tem, Mortality_Num, marker='o')
plt.xlabel('Maximum Temperature') 
plt.ylabel('death toll') 
plt.title('California')
plt.show()

# %%
florida_data.to_csv('florida_data.csv',index=False,mode='a',encoding='utf-8-sig')

# %%
Texas_data.to_csv('Texas_data.csv',index=False,mode='a',encoding='utf-8-sig')

# %%
New_York_data.to_csv('New_York_data.csv',index=False,mode='a',encoding='utf-8-sig')

# %%
California_data.to_csv('California_data.csv',index=False,mode='a',encoding='utf-8-sig')
